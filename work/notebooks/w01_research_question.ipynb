# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing the **Ranking / Scoring** lane. This lane is the most impactful for my objective because the primary challenge for content editors is not a lack of content, but a lack of effective prioritization. With thousands of articles across different clients, knowing "which five items to tackle this week" transforms a manual, overwhelming process into a targeted, data-informed workflow.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# * **Decision:** Which 5 articles should an editor refresh this week to maximize engagement impact?
# * **Action:** The editor reviews the top 5 ranked recommendations provided by the model and selects them for manual SEO optimization or content updates.
# * **Cost of a wrong call:** Wasted editorial hours on content that was unlikely to improve, which carries the opportunity cost of neglecting other, higher-potential content that actually required attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# 1. Clone your repo (Replace with your actual URL)
# !git clone https://github.com/Saree-tech/FlyRank_repo.git

# 2. Change into the repo directory
import os
os.chdir('FlyRank_repo')

# 3. Verify files are present
print("Current folder contents:", os.listdir('.'))
# You should now see 'data' in the list above
# Out:
# Cloning into 'FlyRank_repo'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 119 (delta 35), reused 77 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.85 MiB | 7.79 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Current folder contents: ['requirements.txt', 'outputs', 'data', '.github', '.gitignore', 'SETUP.md', '.git', 'docs', 'skills', 'README.md', 'submission', 'notebooks', 'AGENTS.md', 'work', 'CLAUDE.md', 'GUIDE.md', 'scripts', 'LICENSE', 'DATA_USE.md']

# %%
import os

# 1. Print current location
print(f"Current working directory: {os.getcwd()}")

# 2. List files to confirm where your data is
print("Contents of current folder:", os.listdir('.'))

# 3. If you see your repo name, change into it:
# os.chdir('your-repo-name')

# 4. Now load the data using the path that matches your file browser
# If the file is in 'data/raw/content_refresh_anonymized.csv' relative to your root:
df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
print("Data loaded successfully!")
# Out:
# Current working directory: /content/FlyRank_repo
# Contents of current folder: ['requirements.txt', 'outputs', 'data', '.github', '.gitignore', 'SETUP.md', '.git', 'docs', 'skills', 'README.md', 'submission', 'notebooks', 'AGENTS.md', 'work', 'CLAUDE.md', 'GUIDE.md', 'scripts', 'LICENSE', 'DATA_USE.md']
# Data loaded successfully!

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work will provide decision-support results. I can claim that the model identifies content items with historical patterns associated with high-engagement growth (an observed result). I cannot claim causal proof that these updates cause the traffic growth, nor am I 'predicting Google'—I am prioritizing content based on patterns found in the provided performance signals.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
