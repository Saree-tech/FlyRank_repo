# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the **Ranking / Scoring** lane. This lane is the most impactful for my objective because the primary challenge for content editors is not a lack of content, but a lack of prioritization. With thousands of articles across different clients, knowing 'which five items to tackle this week' transforms a manual, overwhelming process into a targeted, data-informed workflow.

# %%
# The lane is selected as 'Ranking / Scoring' because it maps directly to prioritizing content for editorial intervention.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# * **Decision:** Which 5 articles should an editor refresh this week to maximize engagement impact?
# * **Action:** The editor reviews the top 5 ranked recommendations provided by the model and selects them for manual SEO optimization or content updates.
# * **Cost of a wrong call:** Wasted editorial hours on content that was unlikely to improve, which carries the opportunity cost of neglecting other content that actually required attention.

# %%
# Decision: Prioritize content for refresh.
# Action: Editor performs manual updates on top 5 recommended items.
# Cost: Opportunity cost of wasted engineering/editorial time.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# * **Data Scale:** The starter set contains 30,000 unique content items, providing a sufficiently large pool to test a ranking model.
# * **Data Health:** There are 1,205 items where `avg_position` is 0. This confirms I must treat 'no data' as a category rather than a numerical zero to avoid model bias.
# * **Signal Potential:** The mean `ctr` of 0.76 (0.76%) provides a baseline. The variance in signals across 32 clients justifies using an ML approach to identify patterns that are too tangled for manual rule-based systems.

# %%
import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

print(f"Total items: {len(df)}")
print(f"Items with no position data (avg_position == 0): {df[df['avg_position'] == 0].shape[0]}")
print(f"Average CTR: {df['ctr'].mean():.4f}")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will provide **decision-support** results. I can claim that the model identifies items with historical patterns associated with high-engagement growth (an **observed** result). I cannot claim **causal proof** that these updates *cause* the traffic growth, nor am I 'predicting Google'—I am prioritizing content based on patterns found in the provided performance signals.

# %%
# Scope: Decision-support, observed patterns, directional results.
# Exclusions: Causal proof, predictive certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
